# %%
#Importing Relevant Libraries
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#Reading the Data
df = pd.read_excel(r'Samples for Python.xlsx', sheet_name='Data Sample')
df

#Creating the Pie Chart
df["Segment"].value_counts().plot(kind='pie', fig=plt.figure(figsize =(10,10)), autopct='%1.0f%%')
shadow=True
ax = plt.gca()
ax.get_yaxis().set_visible(False)
plt.title("Percentage of Sales per Segment", fontweight='bold')
plt.legend (loc="right", bbox_to_anchor =(0.2,0))
plt.rcParams.update({'font.size': 20})

#Creating the Table
table=pd.crosstab(index=df['Region'], columns = 'Region').apply(lambda r: r/len(df), axis=1)
table.style.set_table_styles([{'selector' : '','props' : [('border','2px solid black')]}])
# Out:
# <style type="text/css">
# #T_e5d2d  {
#   border: 2px solid black;
# }
# </style>
# <table id="T_e5d2d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col_0</th>
#       <th id="T_e5d2d_level0_col0" class="col_heading level0 col0" >Region</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5d2d_level0_row0" class="row_heading level0 row0" >Central</th>
#       <td id="T_e5d2d_row0_col0" class="data row0 col0" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_e5d2d_level0_row1" class="row_heading level0 row1" >East</th>
#       <td id="T_e5d2d_row1_col0" class="data row1 col0" >0.310000</td>
#     </tr>
#     <tr>
#       <th id="T_e5d2d_level0_row2" class="row_heading level0 row2" >South</th>
#       <td id="T_e5d2d_row2_col0" class="data row2 col0" >0.150000</td>
#     </tr>
#     <tr>
# ...

# %%
#Importing Relevant Libraries
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#Reading the Data
df = pd.read_excel(r'Samples for Python.xlsx', sheet_name='Data Sample')
df

#Creating the Pie Chart
df["Segment"].value_counts().plot(kind='pie', fig=plt.figure(figsize =(10,10)), autopct='%1.0f%%')
shadow=True
ax = plt.gca()
ax.get_yaxis().set_visible(False)
plt.title("Percentage of Sales per Segment", fontweight='bold')
plt.legend (loc="right", bbox_to_anchor =(0.2,1))
plt.rcParams.update({'font.size': 15})

#Creating the Table
table=pd.crosstab(index=df['Region'], columns = 'Region').apply(lambda r: r/len(df), axis=1)
table.style.set_table_styles([{'selector' : '','props' : [('border','2px solid black')]}])
# Out:
# <style type="text/css">
# #T_5f2b0  {
#   border: 2px solid black;
# }
# </style>
# <table id="T_5f2b0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col_0</th>
#       <th id="T_5f2b0_level0_col0" class="col_heading level0 col0" >Region</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f2b0_level0_row0" class="row_heading level0 row0" >Central</th>
#       <td id="T_5f2b0_row0_col0" class="data row0 col0" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_5f2b0_level0_row1" class="row_heading level0 row1" >East</th>
#       <td id="T_5f2b0_row1_col0" class="data row1 col0" >0.310000</td>
#     </tr>
#     <tr>
#       <th id="T_5f2b0_level0_row2" class="row_heading level0 row2" >South</th>
#       <td id="T_5f2b0_row2_col0" class="data row2 col0" >0.150000</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/Siriuslyblack/fin10002/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Misc code
# ## more code
# !pip install numpy matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
"introduction".upper().title()
# Out:
# 'Introduction'

# %%
df= pd.read_excel(input('Enter file name here'))
print(df)
# Out:
# Enter file name here'Major Assignment.xlsx'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-ecf0a4443adb> in <cell line: 1>()
# ----> 1 df= pd.read_excel(input('Enter file name here'))
#       2 print(df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
subjects =['marketing','management','statistics','accounting']
subjects

# %%
def sum_values(a):

  x =a*a
  return x

# %%
sum_values(9898989898989898989)

# %%
# !pip install segno

# %%
import statistics

# %%
int_rand = np.random.randint(1,190,size = 900)

# %%
df = pd.read_excel('Samples for Python 2.xlsx')
round(df['Quantity'].mean(),2)
df.sort_values('Order Date',ascending =False,key=lambda col:col)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Web Extension extension is not supported and will be removed
#   warn(msg)
#     Order Date       Ship Mode      Segment   Region         Category  \
# 199 2017-12-29    Second Class     Consumer    South        Furniture
# 198 2017-12-28  Standard Class     Consumer  Central  Office Supplies
# 197 2017-12-23  Standard Class     Consumer    South  Office Supplies
# 196 2017-12-22        Same Day     Consumer  Central        Furniture
# 195 2017-12-21  Standard Class  Home Office     East  Office Supplies
# ..         ...             ...          ...      ...              ...
# 4   2014-04-26  Standard Class    Corporate     East  Office Supplies
# 3   2014-03-03  Standard Class     Consumer     East       Technology
# 2   2014-02-18  Standard Class    Corporate     West       Technology
# 1   2014-02-02    Second Class     Consumer  Central  Office Supplies
# ...

# %%
df.pivot_table(index='Category',
               columns='Ship Mode',
               aggfunc ='sum')
# Out:
# <ipython-input-33-4d6c96ae0637>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df.pivot_table(index='Category',
#                    Discount                                        Frequency  \
# Ship Mode       First Class Same Day Second Class Standard Class First Class
# Category
# Furniture               2.4      0.9          1.2           4.67         0.0
# Office Supplies         2.0      1.1          2.6          12.70         0.0
# Technology              0.8      0.2          1.2           3.50         0.0
#
#                                                      Frequency.1           \
# Ship Mode       Same Day Second Class Standard Class First Class Same Day
# Category
# Furniture            0.0          0.0          117.0         0.0      0.0
# ...

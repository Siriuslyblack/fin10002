# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in /opt/anaconda/lib/python3.11/site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in /opt/anaconda/lib/python3.11/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing the Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

#Reading the Excel Data
df=pd.read_excel(r'Samples for Python.xlsx', sheet_name='Data Sample')
print(df)
# Out:
#     Order Date       Ship Mode      Segment   Region         Category  \
# 0   2017-12-29    Second Class     Consumer    South        Furniture
# 1   2017-12-28  Standard Class     Consumer  Central        Furniture
# 2   2017-12-23    Second Class     Consumer  Central  Office Supplies
# 3   2017-12-22  Standard Class    Corporate     West       Technology
# 4   2017-12-21  Standard Class     Consumer     East       Technology
# ..         ...             ...          ...      ...              ...
# 195 2014-04-26  Standard Class    Corporate     West        Furniture
# 196 2014-03-03  Standard Class  Home Office     East  Office Supplies
# 197 2014-02-18        Same Day     Consumer  Central        Furniture
# 198 2014-02-02  Standard Class     Consumer    South  Office Supplies
# 199 2014-01-07  Standard Class     Consumer  Central  Office Supplies
#
#         Sales  Quantity  Discount   Profit  Unnamed: 9 Unnamed: 10  \
# 0    300.9800         1      0.00  87.2842         NaN         NaN
# 1     78.8528         2      0.32 -11.5960         NaN         NaN
# 2     28.6720         8      0.20  10.3936         NaN         NaN
# 3     67.0400         4      0.20   6.7040         NaN         NaN
# 4    281.9700         3      0.00  78.9516         NaN         NaN
# ..        ...       ...       ...      ...         ...         ...
# 195  230.2800         3      0.20  23.0280         NaN         NaN
# 196   25.3200         5      0.20   9.1785         NaN         NaN
# 197   25.1600         5      0.60 -11.3220         NaN         NaN
# 198   18.3360         2      0.70 -12.2240         NaN         NaN
# 199   10.4300         7      0.80 -18.2525         NaN         NaN
#
#        Segment.1  Frequency Unnamed: 13     Ship Mode.1  Frequency.1
# 0       Consumer      117.0         NaN     First Class         33.0
# 1      Corporate       51.0         NaN        Same Day          8.0
# 2    Home Office       32.0         NaN  Standard Class        118.0
# 3            NaN        NaN         NaN    Second Class         41.0
# 4            NaN        NaN         NaN             NaN          NaN
# ..           ...        ...         ...             ...          ...
# 195          NaN        NaN         NaN             NaN          NaN
# 196          NaN        NaN         NaN             NaN          NaN
# 197          NaN        NaN         NaN             NaN          NaN
# 198          NaN        NaN         NaN             NaN          NaN
# 199          NaN        NaN         NaN             NaN          NaN
#
# [200 rows x 16 columns]

# %%
#To obtain the Values
freq_table = pd.crosstab(df['Segment'], 'Frequency')
freq_table
# Out:
# col_0        Frequency
# Segment
# Consumer           117
# Corporate           51
# Home Office         32

# %%
#Generating the bar Chart
import matplotlib.pyplot as plt

def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')
  
if __name__ == '__main__':
    y = [117,51,32]
    x = ["Consumer","Corporate","Home Office"]

    plt.figure(figsize = (10,10))

    plt.bar(x, y)

    addlabels(x, y)
    plt.title("Frequency of Sales by Segment", fontweight='bold',  fontsize=20)
    plt.xlabel("Segments", fontweight='bold',  fontsize=20)
    plt.ylabel("Frequency", fontweight='bold',  fontsize=20)
    plt.xticks(x, rotation=10)
    plt.rcParams.update({'font.size':20})
    
#Generating the Table
table=pd.crosstab(index=df['Segment'], columns = 'Frequency')
table

#Adding Table Border
table.style.set_table_styles([{'selector' : '','props' : [('border','2px solid black')]}])
# Out:
# <style type="text/css">
# #T_f285c  {
#   border: 2px solid black;
# }
# </style>
# <table id="T_f285c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col_0</th>
#       <th id="T_f285c_level0_col0" class="col_heading level0 col0" >Frequency</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Segment</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f285c_level0_row0" class="row_heading level0 row0" >Consumer</th>
#       <td id="T_f285c_row0_col0" class="data row0 col0" >117</td>
#     </tr>
#     <tr>
#       <th id="T_f285c_level0_row1" class="row_heading level0 row1" >Corporate</th>
#       <td id="T_f285c_row1_col0" class="data row1 col0" >51</td>
#     </tr>
#     <tr>
#       <th id="T_f285c_level0_row2" class="row_heading level0 row2" >Home Office</th>
#       <td id="T_f285c_row2_col0" class="data row2 col0" >32</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Importing Relevant Libraries
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#Reading the Data
df = pd.read_excel(r'Samples for Python.xlsx', sheet_name='Data Sample')
df

#Creating the Pie Chart
df["Segment"].value_counts().plot(kind='pie', fig=plt.figure(figsize =(10,10)), autopct='%1.0f%%')
shadow=True
ax = plt.gca()
ax.get_yaxis().set_visible(False)
plt.title("Percentage of Sales per Region", fontweight='bold')
plt.legend (loc="right", bbox_to_anchor =(0.2,0))
plt.rcParams.update({'font.size': 20})

#Creating the Table
table=pd.crosstab(index=df['Region'], columns = 'Region').apply(lambda r: r/len(df), axis=1)
table.style.set_table_styles([{'selector' : '','props' : [('border','2px solid black')]}])
# Out:
# <style type="text/css">
# #T_86342  {
#   border: 2px solid black;
# }
# </style>
# <table id="T_86342">
#   <thead>
#     <tr>
#       <th class="index_name level0" >col_0</th>
#       <th id="T_86342_level0_col0" class="col_heading level0 col0" >Region</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86342_level0_row0" class="row_heading level0 row0" >Central</th>
#       <td id="T_86342_row0_col0" class="data row0 col0" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_86342_level0_row1" class="row_heading level0 row1" >East</th>
#       <td id="T_86342_row1_col0" class="data row1 col0" >0.310000</td>
#     </tr>
#     <tr>
#       <th id="T_86342_level0_row2" class="row_heading level0 row2" >South</th>
#       <td id="T_86342_row2_col0" class="data row2 col0" >0.150000</td>
#     </tr>
#     <tr>
#       <th id="T_86342_level0_row3" class="row_heading level0 row3" >West</th>
#       <td id="T_86342_row3_col0" class="data row3 col0" >0.290000</td>
#     </tr>
#   </tbody>
# </table>
